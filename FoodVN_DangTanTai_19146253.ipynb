# %% [markdown]
# <a href="https://colab.research.google.com/github/DangTanTai/AI/blob/main/FoodVN_DangTanTai_19146253.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras import datasets, Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from keras.utils import np_utils
from keras.datasets import cifar10
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import  image
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator
import numpy as np
import os
import cv2 as cv

# %%
thuc_an = ['BanhMi','BanhUot','BanhXeo','ComTam','HeoQuay','KhoQuaNhoiThit','LongGaXaoMuop','Pho','ThitKho','Xoi']
dir_train = '/content/drive/MyDrive/FoodVN' 
distpath = []
y_train = []
x_train = []
x_test = []
y_test = []
# Tạo dữ liệu
def create_data(dir, x_train, y_train):
  for i in thuc_an:
    path = os.path.join(dir,i)
    index_label = thuc_an.index(i)
    for j in os.listdir(path):
      img_path = os.path.join(path, j)
      img = image.load_img(img_path, target_size=(150,150)) 
      img = img_to_array(img)
      img = img.reshape(150,150,3) 
      img = img.astype('float32')
      img = img/255
      x_train.append(img)
      y_train.append(index_label)
create_data(dir_train, x_train, y_train) 
# xử lí dữ liệu
x_train = np.array(x_train)
y_train = np.array(y_train)
y_train = np_utils.to_categorical(y_train, 10)
print(x_train.shape) 
print(y_train.shape)
model = Sequential()
model.add(Conv2D(filters=32,
                 kernel_size=(27,48),
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same',
                 input_shape=(150,150,3),
                 strides=(9,16)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=64,
                 kernel_size=(27,48), 
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=128,
                 kernel_size=(27,48), 
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu',input_shape=(67500,), name='layer1')) 
model.add(Dense(1028, activation='relu', name='layer2'))
model.add(Dense(1028, activation='relu', name='layer3'))
model.add(Dense(10, activation='softmax', name='layer4'))
model.summary()
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
history = model.fit(x_train,y_train,epochs = 100, verbose=1,batch_size=40)
# Out:
# (249, 150, 150, 3)
# (249, 10)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 17, 10, 32)        124448
#
#  max_pooling2d (MaxPooling2D  (None, 8, 5, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 5, 64)          2654272
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 2, 128)         10616960
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  layer1 (Dense)              (None, 512)               131584
#
#  layer2 (Dense)              (None, 1028)              527364
#
#  layer3 (Dense)              (None, 1028)              1057812
#
#  layer4 (Dense)              (None, 10)                10290
#
# =================================================================
# Total params: 15,122,730
# Trainable params: 15,122,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.3358 - accuracy: 0.1446
# Epoch 2/100
# 7/7 [==============================] - 15s 2s/step - loss: 2.2386 - accuracy: 0.1606
# Epoch 3/100
# 7/7 [==============================] - 15s 2s/step - loss: 2.1908 - accuracy: 0.1606
# Epoch 4/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.1958 - accuracy: 0.1606
# Epoch 5/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.1988 - accuracy: 0.1446
# Epoch 6/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.1623 - accuracy: 0.1606
# Epoch 7/100
# 7/7 [==============================] - 15s 2s/step - loss: 2.1588 - accuracy: 0.1647
# Epoch 8/100
# 7/7 [==============================] - 15s 2s/step - loss: 2.1129 - accuracy: 0.1325
# Epoch 9/100
# 7/7 [==============================] - 15s 2s/step - loss: 2.0093 - accuracy: 0.1807
# Epoch 10/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.9439 - accuracy: 0.2892
# Epoch 11/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.8025 - accuracy: 0.2892
# Epoch 12/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.7886 - accuracy: 0.3333
# Epoch 13/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.7139 - accuracy: 0.3333
# Epoch 14/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.7130 - accuracy: 0.2892
# Epoch 15/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.5748 - accuracy: 0.3534
# Epoch 16/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.4759 - accuracy: 0.4257
# Epoch 17/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.4370 - accuracy: 0.4217
# Epoch 18/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.3530 - accuracy: 0.4578
# Epoch 19/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.3843 - accuracy: 0.4257
# Epoch 20/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.2673 - accuracy: 0.4900
# Epoch 21/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.2880 - accuracy: 0.4980
# Epoch 22/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.2340 - accuracy: 0.5100
# Epoch 23/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.2068 - accuracy: 0.5100
# Epoch 24/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.1624 - accuracy: 0.5020
# Epoch 25/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.1150 - accuracy: 0.5100
# Epoch 26/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.0515 - accuracy: 0.5863
# Epoch 27/100
# 7/7 [==============================] - 15s 2s/step - loss: 1.0451 - accuracy: 0.5382
# Epoch 28/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.9255 - accuracy: 0.6064
# Epoch 29/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.9090 - accuracy: 0.5944
# Epoch 30/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.9483 - accuracy: 0.5863
# Epoch 31/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.8426 - accuracy: 0.6506
# Epoch 32/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.8148 - accuracy: 0.6265
# Epoch 33/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.7665 - accuracy: 0.6627
# Epoch 34/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.7274 - accuracy: 0.6707
# Epoch 35/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6514 - accuracy: 0.6948
# Epoch 36/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6862 - accuracy: 0.6667
# Epoch 37/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6508 - accuracy: 0.6948
# Epoch 38/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6960 - accuracy: 0.6908
# Epoch 39/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.7987 - accuracy: 0.6386
# Epoch 40/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6974 - accuracy: 0.6707
# Epoch 41/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6694 - accuracy: 0.6747
# Epoch 42/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6716 - accuracy: 0.6787
# Epoch 43/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6867 - accuracy: 0.6827
# Epoch 44/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4994 - accuracy: 0.7470
# Epoch 45/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4591 - accuracy: 0.8153
# Epoch 46/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4767 - accuracy: 0.7510
# Epoch 47/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4085 - accuracy: 0.7992
# Epoch 48/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4042 - accuracy: 0.8193
# Epoch 49/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.3650 - accuracy: 0.8594
# Epoch 50/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.3567 - accuracy: 0.8353
# Epoch 51/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4854 - accuracy: 0.7831
# Epoch 52/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.7344 - accuracy: 0.6948
# Epoch 53/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.5400 - accuracy: 0.7510
# Epoch 54/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5861 - accuracy: 0.7590
# Epoch 55/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4418 - accuracy: 0.8353
# Epoch 56/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.3807 - accuracy: 0.8273
# Epoch 57/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5339 - accuracy: 0.7992
# Epoch 58/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6007 - accuracy: 0.7349
# Epoch 59/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.5622 - accuracy: 0.7791
# Epoch 60/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.5035 - accuracy: 0.8153
# Epoch 61/100
# 7/7 [==============================] - 16s 2s/step - loss: 1.5145 - accuracy: 0.5703
# Epoch 62/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.7709 - accuracy: 0.7068
# Epoch 63/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6174 - accuracy: 0.7510
# Epoch 64/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.4123 - accuracy: 0.8554
# Epoch 65/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.2905 - accuracy: 0.9036
# Epoch 66/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1777 - accuracy: 0.9639
# Epoch 67/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1364 - accuracy: 0.9558
# Epoch 68/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.3904 - accuracy: 0.9116
# Epoch 69/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1339 - accuracy: 0.9639
# Epoch 70/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1507 - accuracy: 0.9518
# Epoch 71/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1912 - accuracy: 0.9398
# Epoch 72/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1290 - accuracy: 0.9679
# Epoch 73/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1257 - accuracy: 0.9398
# Epoch 74/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.2538 - accuracy: 0.9237
# Epoch 75/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.3538 - accuracy: 0.8916
# Epoch 76/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1996 - accuracy: 0.9478
# Epoch 77/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1688 - accuracy: 0.9398
# Epoch 78/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1323 - accuracy: 0.9558
# Epoch 79/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1405 - accuracy: 0.9518
# Epoch 80/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1308 - accuracy: 0.9598
# Epoch 81/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0657 - accuracy: 0.9759
# Epoch 82/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0391 - accuracy: 0.9920
# Epoch 83/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 16s 2s/step - loss: 9.1543e-04 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 16s 2s/step - loss: 7.7818e-04 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 16s 2s/step - loss: 6.1852e-04 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 16s 2s/step - loss: 5.2066e-04 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 16s 2s/step - loss: 4.2579e-04 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 16s 2s/step - loss: 3.5345e-04 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.9181e-04 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.3629e-04 - accuracy: 1.0000

# %%
model.save('food.h5')

# %%
filename = '/content/drive/MyDrive/Test_food/testbanhmi.jpg'  
food = image.load_img(filename, target_size=(150,150))
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(food)))
if np.argmax(model.predict(food)) == 0:
   print("Bánh Mì")
if np.argmax(model.predict(food)) == 1:
   print("Bánh Ướt")
if np.argmax(model.predict(food)) == 2:
   print("Bánh Xèo")
if np.argmax(model.predict(food)) == 3:
   print("Cơm Tấm")
if np.argmax(model.predict(food)) == 4:
   print("Heo Quay")
if np.argmax(model.predict(food)) == 5:
   print("Khổ Qua Nhồi Thịt")
if np.argmax(model.predict(food)) == 6:
   print("Lòng Gà Xào Mướp")
if np.argmax(model.predict(food)) == 7:
   print("Phở")
if np.argmax(model.predict(food)) == 8:
   print("Thịt Kho")
if np.argmax(model.predict(food)) == 9:
   print("Xôi")
# Out:
# Giá trị dự đoán: 0
# Bánh Mì

# %%
filename1 = '/content/drive/MyDrive/Test_food/testxoi.jpg'  
food = image.load_img(filename1, target_size=(150,150)) 
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(food)))
if np.argmax(model.predict(food)) == 0:
   print("Bánh Mì")
if np.argmax(model.predict(food)) == 1:
   print("Bánh Ướt")
if np.argmax(model.predict(food)) == 2:
   print("Bánh Xèo")
if np.argmax(model.predict(food)) == 3:
   print("Cơm Tấm")
if np.argmax(model.predict(food)) == 4:
   print("Heo Quay")
if np.argmax(model.predict(food)) == 5:
   print("Khổ Qua Nhồi Thịt")
if np.argmax(model.predict(food)) == 6:
   print("Lòng Gà Xào Mướp")
if np.argmax(model.predict(food)) == 7:
   print("Phở")
if np.argmax(model.predict(food)) == 8:
   print("Thịt Kho")
if np.argmax(model.predict(food)) == 9:
   print("Xôi")
# Out:
# Giá trị dự đoán: 9
# Xôi

# %%
filename2 = '/content/drive/MyDrive/Test_food/testthitkho.jpg'  
food = image.load_img(filename2, target_size=(150,150)) 
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(food)))
if np.argmax(model.predict(food)) == 0:
   print("Bánh Mì")
if np.argmax(model.predict(food)) == 1:
   print("Bánh Ướt")
if np.argmax(model.predict(food)) == 2:
   print("Bánh Xèo")
if np.argmax(model.predict(food)) == 3:
   print("Cơm Tấm")
if np.argmax(model.predict(food)) == 4:
   print("Heo Quay")
if np.argmax(model.predict(food)) == 5:
   print("Khổ Qua Nhồi Thịt")
if np.argmax(model.predict(food)) == 6:
   print("Lòng Gà Xào Mướp")
if np.argmax(model.predict(food)) == 7:
   print("Phở")
if np.argmax(model.predict(food)) == 8:
   print("Thịt Kho")
if np.argmax(model.predict(food)) == 9:
   print("Xôi")
# Out:
# Giá trị dự đoán: 8
# Thịt Kho

# %%
filename3 = '/content/drive/MyDrive/Test_food/HeoQuay/2.jpg'  
food = image.load_img(filename3, target_size=(150,150)) 
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(food)))
if np.argmax(model.predict(food)) == 0:
   print("Bánh Mì")
if np.argmax(model.predict(food)) == 1:
   print("Bánh Ướt")
if np.argmax(model.predict(food)) == 2:
   print("Bánh Xèo")
if np.argmax(model.predict(food)) == 3:
   print("Cơm Tấm")
if np.argmax(model.predict(food)) == 4:
   print("Heo Quay")
if np.argmax(model.predict(food)) == 5:
   print("Khổ Qua Nhồi Thịt")
if np.argmax(model.predict(food)) == 6:
   print("Lòng Gà Xào Mướp")
if np.argmax(model.predict(food)) == 7:
   print("Phở")
if np.argmax(model.predict(food)) == 8:
   print("Thịt Kho")
if np.argmax(model.predict(food)) == 9:
   print("Xôi")
# Out:
# Giá trị dự đoán: 4
# Heo Quay

# %%
filename3 = '/content/drive/MyDrive/Test_food/Pho/2.jpg'  
food = image.load_img(filename3, target_size=(150,150)) 
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(food)))
if np.argmax(model.predict(food)) == 0:
   print("Bánh Mì")
if np.argmax(model.predict(food)) == 1:
   print("Bánh Ướt")
if np.argmax(model.predict(food)) == 2:
   print("Bánh Xèo")
if np.argmax(model.predict(food)) == 3:
   print("Cơm Tấm")
if np.argmax(model.predict(food)) == 4:
   print("Heo Quay")
if np.argmax(model.predict(food)) == 5:
   print("Khổ Qua Nhồi Thịt")
if np.argmax(model.predict(food)) == 6:
   print("Lòng Gà Xào Mướp")
if np.argmax(model.predict(food)) == 7:
   print("Phở")
if np.argmax(model.predict(food)) == 8:
   print("Thịt Kho")
if np.argmax(model.predict(food)) == 9:
   print("Xôi")
# Out:
# Giá trị dự đoán: 7
# Phở
