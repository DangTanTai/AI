# %% [markdown]
# <a href="https://colab.research.google.com/github/DangTanTai/AI/blob/main/Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras import datasets, Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from keras.utils import np_utils
from keras.datasets import cifar10
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import  image
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator
import numpy as np
import os
import cv2 as cv

# %%
face = ['Dang_Tai','Kim_Bao','Thuy_Hien']
dir_train = '/content/drive/MyDrive/Face' 
distpath = []
y_train = []
x_train = []
x_test = []
y_test = []
# Tạo dữ liệu
def create_data(dir, x_train, y_train):
  for i in face:
    path = os.path.join(dir,i)
    index_label = face.index(i)
    for j in os.listdir(path):
      img_path = os.path.join(path, j)
      img = image.load_img(img_path, target_size=(150,150)) 
      img = img_to_array(img)
      img = img.reshape(150,150,3) 
      img = img.astype('float32')
      img = img/255
      x_train.append(img)
      y_train.append(index_label)
create_data(dir_train, x_train, y_train) 
# xử lí dữ liệu
x_train = np.array(x_train)
y_train = np.array(y_train)
y_train = np_utils.to_categorical(y_train, 3)
print(x_train.shape) 
print(y_train.shape)
model = Sequential()
model.add(Conv2D(filters=32,
                 kernel_size=(27,48),
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same',
                 input_shape=(150,150,3),
                 strides=(9,16)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=64,
                 kernel_size=(27,48), 
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=128,
                 kernel_size=(27,48), 
                 activation='relu',
                 kernel_initializer='he_uniform',
                 padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu',input_shape=(67500,), name='layer1')) 
model.add(Dense(1028, activation='relu', name='layer2'))
model.add(Dense(1028, activation='relu', name='layer3'))
model.add(Dense(3, activation='softmax', name='layer4'))
model.summary()
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
history = model.fit(x_train,y_train,epochs = 50,verbose=1,batch_size=10)
# Out:
# (75, 150, 150, 3)
# (75, 3)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 17, 10, 32)        124448
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 5, 32)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 5, 64)          2654272
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 2, 128)         10616960
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 1, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  layer1 (Dense)              (None, 512)               131584
#
#  layer2 (Dense)              (None, 1028)              527364
#
#  layer3 (Dense)              (None, 1028)              1057812
#
#  layer4 (Dense)              (None, 3)                 3087
#
# =================================================================
# Total params: 15,115,527
# Trainable params: 15,115,527
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 8/8 [==============================] - 6s 716ms/step - loss: 1.1046 - accuracy: 0.3067
# Epoch 2/50
# 8/8 [==============================] - 6s 708ms/step - loss: 1.0262 - accuracy: 0.4400
# Epoch 3/50
# 8/8 [==============================] - 6s 714ms/step - loss: 0.4063 - accuracy: 0.7733
# Epoch 4/50
# 8/8 [==============================] - 6s 711ms/step - loss: 0.1330 - accuracy: 0.9600
# Epoch 5/50
# 8/8 [==============================] - 6s 712ms/step - loss: 0.0597 - accuracy: 0.9600
# Epoch 6/50
# 8/8 [==============================] - 6s 717ms/step - loss: 0.0970 - accuracy: 0.9467
# Epoch 7/50
# 8/8 [==============================] - 6s 722ms/step - loss: 0.0296 - accuracy: 0.9733
# Epoch 8/50
# 8/8 [==============================] - 6s 720ms/step - loss: 0.0957 - accuracy: 0.9733
# Epoch 9/50
# 8/8 [==============================] - 6s 811ms/step - loss: 0.0550 - accuracy: 0.9867
# Epoch 10/50
# 8/8 [==============================] - 6s 718ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 11/50
# 8/8 [==============================] - 6s 717ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 12/50
# 8/8 [==============================] - 6s 708ms/step - loss: 8.8307e-05 - accuracy: 1.0000
# Epoch 13/50
# 8/8 [==============================] - 6s 704ms/step - loss: 2.9212e-05 - accuracy: 1.0000
# Epoch 14/50
# 8/8 [==============================] - 6s 717ms/step - loss: 8.7180e-06 - accuracy: 1.0000
# Epoch 15/50
# 8/8 [==============================] - 6s 723ms/step - loss: 1.5529e-06 - accuracy: 1.0000
# Epoch 16/50
# 8/8 [==============================] - 6s 712ms/step - loss: 7.8360e-07 - accuracy: 1.0000
# Epoch 17/50
# 8/8 [==============================] - 6s 732ms/step - loss: 6.2147e-07 - accuracy: 1.0000
# Epoch 18/50
# 8/8 [==============================] - 6s 715ms/step - loss: 5.5948e-07 - accuracy: 1.0000
# Epoch 19/50
# 8/8 [==============================] - 6s 710ms/step - loss: 5.2770e-07 - accuracy: 1.0000
# Epoch 20/50
# 8/8 [==============================] - 6s 715ms/step - loss: 5.1021e-07 - accuracy: 1.0000
# Epoch 21/50
# 8/8 [==============================] - 6s 718ms/step - loss: 4.8001e-07 - accuracy: 1.0000
# Epoch 22/50
# 8/8 [==============================] - 6s 722ms/step - loss: 4.5617e-07 - accuracy: 1.0000
# Epoch 23/50
# 8/8 [==============================] - 6s 718ms/step - loss: 4.2915e-07 - accuracy: 1.0000
# Epoch 24/50
# 8/8 [==============================] - 6s 718ms/step - loss: 4.1961e-07 - accuracy: 1.0000
# Epoch 25/50
# 8/8 [==============================] - 6s 723ms/step - loss: 3.8783e-07 - accuracy: 1.0000
# Epoch 26/50
# 8/8 [==============================] - 6s 715ms/step - loss: 3.7193e-07 - accuracy: 1.0000
# Epoch 27/50
# 8/8 [==============================] - 6s 707ms/step - loss: 3.6239e-07 - accuracy: 1.0000
# Epoch 28/50
# 8/8 [==============================] - 6s 711ms/step - loss: 3.4491e-07 - accuracy: 1.0000
# Epoch 29/50
# 8/8 [==============================] - 6s 706ms/step - loss: 3.3537e-07 - accuracy: 1.0000
# Epoch 30/50
# 8/8 [==============================] - 6s 709ms/step - loss: 3.1789e-07 - accuracy: 1.0000
# Epoch 31/50
# 8/8 [==============================] - 6s 700ms/step - loss: 3.0676e-07 - accuracy: 1.0000
# Epoch 32/50
# 8/8 [==============================] - 6s 712ms/step - loss: 2.8928e-07 - accuracy: 1.0000
# Epoch 33/50
# 8/8 [==============================] - 6s 695ms/step - loss: 2.7656e-07 - accuracy: 1.0000
# Epoch 34/50
# 8/8 [==============================] - 6s 709ms/step - loss: 2.6862e-07 - accuracy: 1.0000
# Epoch 35/50
# 8/8 [==============================] - 6s 704ms/step - loss: 2.6067e-07 - accuracy: 1.0000
# Epoch 36/50
# 8/8 [==============================] - 6s 708ms/step - loss: 2.4637e-07 - accuracy: 1.0000
# Epoch 37/50
# 8/8 [==============================] - 6s 707ms/step - loss: 2.3683e-07 - accuracy: 1.0000
# Epoch 38/50
# 8/8 [==============================] - 6s 706ms/step - loss: 2.3047e-07 - accuracy: 1.0000
# Epoch 39/50
# 8/8 [==============================] - 6s 696ms/step - loss: 2.1934e-07 - accuracy: 1.0000
# Epoch 40/50
# 8/8 [==============================] - 6s 700ms/step - loss: 2.1299e-07 - accuracy: 1.0000
# Epoch 41/50
# 8/8 [==============================] - 6s 709ms/step - loss: 2.0345e-07 - accuracy: 1.0000
# Epoch 42/50
# 8/8 [==============================] - 6s 709ms/step - loss: 1.9709e-07 - accuracy: 1.0000
# Epoch 43/50
# 8/8 [==============================] - 6s 706ms/step - loss: 1.8914e-07 - accuracy: 1.0000
# Epoch 44/50
# 8/8 [==============================] - 6s 719ms/step - loss: 1.8279e-07 - accuracy: 1.0000
# Epoch 45/50
# 8/8 [==============================] - 6s 714ms/step - loss: 1.7802e-07 - accuracy: 1.0000
# Epoch 46/50
# 8/8 [==============================] - 6s 723ms/step - loss: 1.7325e-07 - accuracy: 1.0000
# Epoch 47/50
# 8/8 [==============================] - 6s 723ms/step - loss: 1.6689e-07 - accuracy: 1.0000
# Epoch 48/50
# 8/8 [==============================] - 6s 728ms/step - loss: 1.6212e-07 - accuracy: 1.0000
# Epoch 49/50
# 8/8 [==============================] - 6s 727ms/step - loss: 1.5736e-07 - accuracy: 1.0000
# Epoch 50/50
# 8/8 [==============================] - 6s 715ms/step - loss: 1.4941e-07 - accuracy: 1.0000

# %%
model.save('face.h5')

# %%
filename='/content/drive/MyDrive/Test_Face/Kim_Bao/25.jpg'
face = image.load_img(filename, target_size=(150,150)) 
plt.imshow(face)
face = img_to_array(face)
face = face.reshape(1,150,150,3) 
face = face.astype('float32')
face = face/255
np.argmax(model.predict(face), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(face)))
if np.argmax(model.predict(face)) == 0:
   print("Đặng Tài")
if np.argmax(model.predict(face)) == 1:
   print("Kim Bảo")
if np.argmax(model.predict(face)) == 2:
   print("Thúy Hiền")
# Out:
# Giá trị dự đoán: 1
# Kim Bảo

# %%
filename1='/content/drive/MyDrive/Test_Face/Thuy_Hien/33.jpg'
face = image.load_img(filename1, target_size=(150,150)) 
plt.imshow(face)
face = img_to_array(face)
face = face.reshape(1,150,150,3) 
face = face.astype('float32')
face = face/255
np.argmax(model.predict(face), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(face)))
if np.argmax(model.predict(face)) == 0:
   print("Đặng Tài")
if np.argmax(model.predict(face)) == 1:
   print("Kim Bảo")
if np.argmax(model.predict(face)) == 2:
   print("Thúy Hiền")
# Out:
# Giá trị dự đoán: 2
# Thúy Hiền

# %%
filename2='/content/drive/MyDrive/Test_Face/Dang_Tai/27.jpg'
face = image.load_img(filename2, target_size=(150,150)) 
plt.imshow(face)
face = img_to_array(face)
face = face.reshape(1,150,150,3) 
face = face.astype('float32')
face = face/255
np.argmax(model.predict(face), axis=1)
print('Giá trị dự đoán:', np.argmax(model.predict(face)))
if np.argmax(model.predict(face)) == 0:
   print("Đặng Tài")
if np.argmax(model.predict(face)) == 1:
   print("Kim Bảo")
if np.argmax(model.predict(face)) == 2:
   print("Thúy Hiền")
# Out:
# Giá trị dự đoán: 0
# Đặng Tài
